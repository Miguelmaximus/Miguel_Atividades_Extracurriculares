# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos teste
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1 teste
class AtividadeExtracurricular:
    def __init__(self, nome, descricao, participantes):
        self.nome = nome
        self.descricao = descricao
        self.participantes = participantes

    def exibir_dados(self):
        print(f"Atividade: {self.nome}")
        print(f"Descrição: {self.descricao}")
        print("Participantes:")
        for participante in self.participantes:
            print(f" - {participante}")
        print("-" * 40)



atividade1 = AtividadeExtracurricular(
    nome="Futebol",
    descricao="Treinos e jogos aos sábados no ginásio.",
    participantes=["João", "Maria", "Carlos"]
)

atividade2 = AtividadeExtracurricular(
    nome="Clube de Robótica",
    descricao="Projetos com Arduino e programação.",
    participantes=["Ana", "Lucas", "Fernanda"]
)


atividade1.exibir_dados()
atividade2.exibir_dados()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2

class AtividadeExtracurricular:
    def __init__(self, nome, descricao, participantes):
        self.nome = nome
        self.descricao = descricao
        self.participantes = participantes

    def exibir_dados(self):
        print(f"Atividade: {self.nome}")
        print(f"Descrição: {self.descricao}")
        print("Participantes:")
        for participante in self.participantes:
            print(f" - {participante}")
        print("-" * 40)

    def adicionar_participante(self, nome_participante):
        self.participantes.append(nome_participante)
        print(f"{nome_participante} foi adicionado(a) à atividade '{self.nome}'.")

    def remover_participante(self, nome_participante):
        if nome_participante in self.participantes:
            self.participantes.remove(nome_participante)
            print(f"{nome_participante} foi removido(a) da atividade '{self.nome}'.")
        else:
            print(f"{nome_participante} não está na lista de participantes.")

class AtividadeEsportiva(AtividadeExtracurricular):
    def __init__(self, nome, descricao, participantes, modalidade):
        super().__init__(nome, descricao, participantes)  
        self.modalidade = modalidade  

    def exibir_modalidade(self):
        print(f"A modalidade da atividade '{self.nome}' é: {self.modalidade}")

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class AtividadeExtracurricular:
    def __init__(self, nome, descricao, participantes):
        self.nome = nome
        self.__descricao = descricao 
        self.participantes = participantes

   
    def get_descricao(self):
        return self.__descricao

   
    def set_descricao(self, nova_descricao):
        if isinstance(nova_descricao, str) and len(nova_descricao) > 5:
            self.__descricao = nova_descricao
        else:
            print("Descrição inválida. Deve ser uma string com mais de 5 caracteres.")

    def exibir_dados(self):
        print(f"Atividade: {self.nome}")
        print(f"Descrição: {self.__descricao}")
        print("Participantes:")
        for participante in self.participantes:
            print(f" - {participante}")
        print("-" * 40)

    def adicionar_participante(self, nome_participante):
        self.participantes.append(nome_participante)
        print(f"{nome_participante} foi adicionado(a) à atividade '{self.nome}'.")

    def remover_participante(self, nome_participante):
        if nome_participante in self.participantes:
            self.participantes.remove(nome_participante)
            print(f"{nome_participante} foi removido(a) da atividade '{self.nome}'.")
        else:
            print(f"{nome_participante} não está na lista de participantes.")

    
    def verificar_participacao(self):
        qtd = len(self.participantes)
        if qtd == 0:
            print("Não há participantes nesta atividade.")
        elif qtd < 3:
            print(f"Atividade '{self.nome}' com poucos participantes: {qtd}.")
        else:
            print(f"Atividade '{self.nome}' com boa participação: {qtd} participantes.")

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4
import sqlite3


class AtividadeExtracurricular:
    def __init__(self, nome, descricao, participantes):
        self.nome = nome
        self.__descricao = descricao  
        self.participantes = participantes

    
    def get_descricao(self):
        return self.__descricao

    def set_descricao(self, nova_descricao):
        if isinstance(nova_descricao, str) and len(nova_descricao) > 5:
            self.__descricao = nova_descricao
        else:
            print("Descrição inválida. Deve ter mais de 5 caracteres.")

    def exibir_dados(self):
        print(f"Atividade: {self.nome}")
        print(f"Descrição: {self.__descricao}")
        print("Participantes:")
        for participante in self.participantes:
            print(f" - {participante}")
        print("-" * 40)

    def adicionar_participante(self, nome_participante):
        self.participantes.append(nome_participante)
        print(f"{nome_participante} foi adicionado(a) à atividade '{self.nome}'.")

    def remover_participante(self, nome_participante):
        if nome_participante in self.participantes:
            self.participantes.remove(nome_participante)
            print(f"{nome_participante} foi removido(a) da atividade '{self.nome}'.")
        else:
            print(f"{nome_participante} não está na lista de participantes.")

    def verificar_participacao(self):
        qtd = len(self.participantes)
        if qtd == 0:
            print("Não há participantes nesta atividade.")
        elif qtd < 3:
            print(f"Atividade '{self.nome}' com poucos participantes: {qtd}.")
        else:
            print(f"Atividade '{self.nome}' com boa participação: {qtd} participantes.")


class AtividadeEsportiva(AtividadeExtracurricular):
    def __init__(self, nome, descricao, participantes, modalidade):
        super().__init__(nome, descricao, participantes)
        self.modalidade = modalidade

    def exibir_dados(self):
        print(f"[ESPORTE] Atividade: {self.nome}")
        print(f"Modalidade: {self.modalidade}")
        print(f"Descrição: {self.get_descricao()}")
        print("Participantes:")
        for participante in self.participantes:
            print(f" - {participante}")
        print("-" * 40)



def criar_tabela():
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS atividades (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            nome TEXT NOT NULL,
            descricao TEXT NOT NULL
        )
    """)
    conn.commit()
    conn.close()

def inserir_atividade(nome, descricao):
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("INSERT INTO atividades (nome, descricao) VALUES (?, ?)", (nome, descricao))
    conn.commit()
    conn.close()
    print(f"Atividade '{nome}' inserida no banco de dados.")

def consultar_atividades():
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM atividades")
    atividades = cursor.fetchall()
    conn.close()
    print("\n📋 Lista de atividades no banco:")
    for id, nome, descricao in atividades:
        print(f"ID: {id} | Nome: {nome} | Descrição: {descricao}")
    print("-" * 40)

def excluir_atividade_por_id(id):
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("DELETE FROM atividades WHERE id = ?", (id,))
    conn.commit()
    conn.close()
    print(f"Atividade com ID {id} excluída do banco.")



if __name__ == "__main__":
    criar_tabela()

    
    robo = AtividadeExtracurricular("Robótica", "Projeto com Arduino.", ["Ana", "Lucas"])
    futebol = AtividadeEsportiva("Futebol", "Jogo de salão", ["Carlos", "João"], "Futsal")

    robo.exibir_dados()
    robo.verificar_participacao()

    futebol.exibir_dados()
    futebol.adicionar_participante("Pedro")

   
    inserir_atividade(robo.nome, robo.get_descricao())
    inserir_atividade(futebol.nome, futebol.get_descricao())

    
    consultar_atividades()

   
    excluir_atividade_por_id(1)
    consultar_atividades()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5

import sqlite3

# ============================
# PARTE 1, 2 e 3: CLASSE PRINCIPAL E SUBCLASSE
# ============================

class AtividadeExtracurricular:
    def __init__(self, nome, descricao, participantes):
        self.nome = nome
        self.__descricao = descricao  # Atributo privado
        self.participantes = participantes

    def get_descricao(self):
        return self.__descricao

    def set_descricao(self, nova_descricao):
        if isinstance(nova_descricao, str) and len(nova_descricao) > 5:
            self.__descricao = nova_descricao
        else:
            print("Descrição inválida. Deve ter mais de 5 caracteres.")

    def exibir_dados(self):
        print(f"Atividade: {self.nome}")
        print(f"Descrição: {self.__descricao}")
        print("Participantes:")
        for participante in self.participantes:
            print(f" - {participante}")
        print("-" * 40)

    def adicionar_participante(self, nome_participante):
        self.participantes.append(nome_participante)
        print(f"{nome_participante} foi adicionado(a) à atividade '{self.nome}'.")

    def remover_participante(self, nome_participante):
        if nome_participante in self.participantes:
            self.participantes.remove(nome_participante)
            print(f"{nome_participante} foi removido(a) da atividade '{self.nome}'.")
        else:
            print(f"{nome_participante} não está na lista de participantes.")

    def verificar_participacao(self):
        qtd = len(self.participantes)
        if qtd == 0:
            print("Não há participantes nesta atividade.")
        elif qtd < 3:
            print(f"Atividade '{self.nome}' com poucos participantes: {qtd}.")
        else:
            print(f"Atividade '{self.nome}' com boa participação: {qtd} participantes.")


class AtividadeEsportiva(AtividadeExtracurricular):
    def __init__(self, nome, descricao, participantes, modalidade):
        super().__init__(nome, descricao, participantes)
        self.modalidade = modalidade

    def exibir_dados(self):
        print(f"[ESPORTE] Atividade: {self.nome}")
        print(f"Modalidade: {self.modalidade}")
        print(f"Descrição: {self.get_descricao()}")
        print("Participantes:")
        for participante in self.participantes:
            print(f" - {participante}")
        print("-" * 40)

# ============================
# PARTE 4: BANCO DE DADOS COM SQLITE
# ============================

def criar_tabela():
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS atividades (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            nome TEXT NOT NULL,
            descricao TEXT NOT NULL
        )
    """)
    conn.commit()
    conn.close()

def inserir_atividade(nome, descricao):
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("INSERT INTO atividades (nome, descricao) VALUES (?, ?)", (nome, descricao))
    conn.commit()
    conn.close()
    print(f"Atividade '{nome}' inserida no banco de dados.")

def consultar_atividades():
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM atividades")
    atividades = cursor.fetchall()
    conn.close()
    print("\n📋 Lista de atividades no banco:")
    for id, nome, descricao in atividades:
        print(f"ID: {id} | Nome: {nome} | Descrição: {descricao}")
    print("-" * 40)

def excluir_atividade_por_id(id):
    conn = sqlite3.connect("atividades.db")
    cursor = conn.cursor()
    cursor.execute("DELETE FROM atividades WHERE id = ?", (id,))
    conn.commit()
    conn.close()
    print(f"Atividade com ID {id} excluída do banco.")

# ============================
# PARTE 5: MENU INTERATIVO
# ============================

def menu():
    criar_tabela()
    atividades = []

    while True:
        print("\n===== MENU DE ATIVIDADES =====")
        print("1. Cadastrar nova atividade")
        print("2. Cadastrar atividade esportiva")
        print("3. Exibir todas as atividades cadastradas (memória)")
        print("4. Inserir atividades no banco de dados")
        print("5. Consultar banco de dados")
        print("6. Excluir atividade do banco de dados")
        print("0. Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            nome = input("Nome da atividade: ")
            descricao = input("Descrição: ")
            participantes = input("Participantes (separados por vírgula): ").split(',')
            atividade = AtividadeExtracurricular(nome, descricao, [p.strip() for p in participantes])
            atividades.append(atividade)
            print("Atividade comum cadastrada com sucesso.")

        elif opcao == "2":
            nome = input("Nome da atividade esportiva: ")
            descricao = input("Descrição: ")
            participantes = input("Participantes (separados por vírgula): ").split(',')
            modalidade = input("Modalidade esportiva: ")
            atividade = AtividadeEsportiva(nome, descricao, [p.strip() for p in participantes], modalidade)
            atividades.append(atividade)
            print("Atividade esportiva cadastrada com sucesso.")

        elif opcao == "3":
            if atividades:
                for atividade in atividades:
                    atividade.exibir_dados()
            else:
                print("Nenhuma atividade cadastrada na memória.")

        elif opcao == "4":
            for atividade in atividades:
                inserir_atividade(atividade.nome, atividade.get_descricao())

        elif opcao == "5":
            consultar_atividades()

        elif opcao == "6":
            try:
                id_del = int(input("Digite o ID da atividade a ser excluída: "))
                excluir_atividade_por_id(id_del)
            except ValueError:
                print("ID inválido. Digite um número inteiro.")

        elif opcao == "0":
            print("Saindo do sistema. Até logo!")
            break

        else:
            print("Opção inválida. Tente novamente.")

# Executa o menu interativo
if __name__ == "__main__":
    menu()
